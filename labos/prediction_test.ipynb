# %%
from ultralytics import YOLO
from PIL import Image
import cv2

# %%
image = Image.open("./ultralytics/bus.jpg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=810x1080>

# %%
model = YOLO("./ultralytics/yolov8n.pt")

# Prédiction
result = model(image)

# Get result image
result_array = result[0].plot()
# Fix BGR2RGB issue
result_rgb = cv2.cvtColor(result_array, cv2.COLOR_BGR2RGB)
# Save image to PIL format
result_image = Image.fromarray(result_rgb)

display(result_image)
# Out:
# 0: 640x480 4 persons, 1 bus, 1 stop sign, 39.1ms
# Speed: 2.7ms preprocess, 39.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=810x1080>
